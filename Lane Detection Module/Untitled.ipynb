# %%
import numpy as np
from PIL import ImageGrab
import cv2
import time
import pyautogui
from numpy import ones,vstack
from numpy.linalg import lstsq
from directkeys import PressKey,ReleaseKey, W, A, S, D
from statistics import mean

def roi(img, vertices):
    
    #blank mask:
    mask = np.zeros_like(img)   
    
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, 255)
    
    #returning the image only where mask pixels are nonzero
    masked = cv2.bitwise_and(img, mask)
    return masked


def draw_lanes(img, lines, color=[0, 255, 255], thickness=3):

    # if this fails, go with some default line
    try:

        # finds the maximum y value for a lane marker 
        # (since we cannot assume the horizon will always be at the same point.)

        ys = []  
        for i in lines:
            for ii in i:
                ys += [ii[1],ii[3]]
        min_y = min(ys)
        max_y = 600
        new_lines = []
        line_dict = {}

        for idx,i in enumerate(lines):
            for xyxy in i:
                # These four lines:
                # modified from http://stackoverflow.com/questions/21565994/method-to-return-the-equation-of-a-straight-line-given-two-points
                # Used to calculate the definition of a line, given two sets of coords.
                x_coords = (xyxy[0],xyxy[2])
                y_coords = (xyxy[1],xyxy[3])
                A = vstack([x_coords,ones(len(x_coords))]).T
                m, b = lstsq(A, y_coords)[0]

                # Calculating our new, and improved, xs
                x1 = (min_y-b) / m
                x2 = (max_y-b) / m

                line_dict[idx] = [m,b,[int(x1), min_y, int(x2), max_y]]
                new_lines.append([int(x1), min_y, int(x2), max_y])

        final_lanes = {}

        for idx in line_dict:
            final_lanes_copy = final_lanes.copy()
            m = line_dict[idx][0]
            b = line_dict[idx][1]
            line = line_dict[idx][2]
            
            if len(final_lanes) == 0:
                final_lanes[m] = [ [m,b,line] ]
                
            else:
                found_copy = False

                for other_ms in final_lanes_copy:

                    if not found_copy:
                        if abs(other_ms*1.2) > abs(m) > abs(other_ms*0.8):
                            if abs(final_lanes_copy[other_ms][0][1]*1.2) > abs(b) > abs(final_lanes_copy[other_ms][0][1]*0.8):
                                final_lanes[other_ms].append([m,b,line])
                                found_copy = True
                                break
                        else:
                            final_lanes[m] = [ [m,b,line] ]

        line_counter = {}

        for lanes in final_lanes:
            line_counter[lanes] = len(final_lanes[lanes])

        top_lanes = sorted(line_counter.items(), key=lambda item: item[1])[::-1][:2]

        lane1_id = top_lanes[0][0]
        lane2_id = top_lanes[1][0]

        def average_lane(lane_data):
            x1s = []
            y1s = []
            x2s = []
            y2s = []
            for data in lane_data:
                x1s.append(data[2][0])
                y1s.append(data[2][1])
                x2s.append(data[2][2])
                y2s.append(data[2][3])
            return int(mean(x1s)), int(mean(y1s)), int(mean(x2s)), int(mean(y2s)) 

        l1_x1, l1_y1, l1_x2, l1_y2 = average_lane(final_lanes[lane1_id])
        l2_x1, l2_y1, l2_x2, l2_y2 = average_lane(final_lanes[lane2_id])

        return [l1_x1, l1_y1, l1_x2, l1_y2], [l2_x1, l2_y1, l2_x2, l2_y2], lane1_id, lane2_id
    except Exception as e:
        print(str(e))


def process_img(image):
    original_image = image
    # edge detection
    processed_img =  cv2.Canny(image, threshold1 = 200, threshold2=300)
    
    processed_img = cv2.GaussianBlur(processed_img,(5,5),0)
    
    vertices = np.array([[10,500],[10,300],[300,200],[500,200],[800,300],[800,500],
                         ], np.int32)

    processed_img = roi(processed_img, [vertices])

    # more info: http://docs.opencv.org/3.0-beta/doc/py_tutorials/py_imgproc/py_houghlines/py_houghlines.html
    #                                     rho   theta   thresh  min length, max gap:        
    lines = cv2.HoughLinesP(processed_img, 1, np.pi/180, 180,      20,       15)
    m1 = 0
    m2 = 0
    try:
        l1, l2, m1,m2 = draw_lanes(original_image,lines)
        cv2.line(original_image, (l1[0], l1[1]), (l1[2], l1[3]), [0,255,0], 30)
        cv2.line(original_image, (l2[0], l2[1]), (l2[2], l2[3]), [0,255,0], 30)
    except Exception as e:
        print(str(e))
        pass
    try:
        for coords in lines:
            coords = coords[0]
            try:
                cv2.line(processed_img, (coords[0], coords[1]), (coords[2], coords[3]), [255,0,0], 3)
                
                
            except Exception as e:
                print(str(e))
    except Exception as e:
        pass

    return processed_img,original_image, m1, m2

def straight():
    PressKey(W)
    ReleaseKey(A)
    ReleaseKey(D)

def left():
    PressKey(A)
    ReleaseKey(W)
    ReleaseKey(D)
    ReleaseKey(A)

def right():
    PressKey(D)
    ReleaseKey(A)
    ReleaseKey(W)
    ReleaseKey(D)

def slow_ya_roll():
    ReleaseKey(W)
    ReleaseKey(A)
    ReleaseKey(D)


for i in list(range(4))[::-1]:
    print(i+1)
    time.sleep(1)


last_time = time.time()
while True:
    screen =  np.array(ImageGrab.grab(bbox=(0,40,800,640)))
    print('Frame took {} seconds'.format(time.time()-last_time))
    last_time = time.time()
    new_screen,original_image, m1, m2 = process_img(screen)
    #cv2.imshow('window', new_screen)
    cv2.imshow('window2',cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))



    if m1 < 0 and m2 < 0:
        right()
    elif m1 > 0  and m2 > 0:
        left()
    else:
        straight()
    
    #cv2.imshow('window',cv2.cvtColor(screen, cv2.COLOR_BGR2RGB))
    if cv2.waitKey(25) & 0xFF == ord('q'):
        cv2.destroyAllWindows()
        break
# Out:
# 4
# 3
# 2
# 1
# Frame took 0.11170172691345215 seconds
# e:\program\anaconda\envs\tensorflow1\lib\site-packages\ipykernel_launcher.py:49: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
# Frame took 0.7056319713592529 seconds
# Frame took 0.12865209579467773 seconds
# Frame took 0.12224793434143066 seconds
# Frame took 0.12666034698486328 seconds
# Frame took 0.11967897415161133 seconds
# Frame took 0.1316978931427002 seconds
# Frame took 0.1296389102935791 seconds
# Frame took 0.11666369438171387 seconds
# Frame took 0.12166285514831543 seconds
# Frame took 0.1296532154083252 seconds
# Frame took 0.11593985557556152 seconds
# Frame took 0.11719441413879395 seconds
# Frame took 0.11922407150268555 seconds
# Frame took 0.1267080307006836 seconds
# Frame took 0.11865091323852539 seconds
# Frame took 0.11570096015930176 seconds
# Frame took 0.11916494369506836 seconds
# Frame took 0.12973904609680176 seconds
# Frame took 0.12185144424438477 seconds
# Frame took 0.10965776443481445 seconds
# Frame took 0.12113142013549805 seconds
# Frame took 0.11969161033630371 seconds
# Frame took 0.1336383819580078 seconds
# Frame took 0.12668728828430176 seconds
# Frame took 0.12064337730407715 seconds
# Frame took 0.1136941909790039 seconds
# Frame took 0.14613771438598633 seconds
# Frame took 0.11824679374694824 seconds
# Frame took 0.11910367012023926 seconds
# Frame took 0.11342382431030273 seconds
# Frame took 0.11893177032470703 seconds
# Frame took 0.13064098358154297 seconds
# Frame took 0.12170934677124023 seconds
# Frame took 0.12719941139221191 seconds
# Frame took 0.1221473217010498 seconds
# Frame took 0.13070011138916016 seconds
# Frame took 0.11472654342651367 seconds
# Frame took 0.11665511131286621 seconds
# Frame took 0.12367081642150879 seconds
# Frame took 0.12864232063293457 seconds
# Frame took 0.11672353744506836 seconds
# Frame took 0.11565446853637695 seconds
# Frame took 0.11474370956420898 seconds
# Frame took 0.13262724876403809 seconds
# Frame took 0.11719846725463867 seconds
# Frame took 0.11560630798339844 seconds
# Frame took 0.11572742462158203 seconds
# Frame took 0.13383221626281738 seconds
# Frame took 0.1310570240020752 seconds
# Frame took 0.11750364303588867 seconds
# Frame took 0.12414669990539551 seconds
# Frame took 0.11018586158752441 seconds
# Frame took 0.11790823936462402 seconds
# Frame took 0.11366629600524902 seconds
# Frame took 0.11967992782592773 seconds
# Frame took 0.12965059280395508 seconds
# Frame took 0.1186830997467041 seconds
# Frame took 0.11469197273254395 seconds
# Frame took 0.119720458984375 seconds
# Frame took 0.13160920143127441 seconds
# Frame took 0.11670970916748047 seconds
# Frame took 0.11568880081176758 seconds
# Frame took 0.11969137191772461 seconds
# Frame took 0.1156916618347168 seconds
# Frame took 0.11769342422485352 seconds
# Frame took 0.1296701431274414 seconds
# Frame took 0.12183308601379395 seconds
# Frame took 0.11217546463012695 seconds
# Frame took 0.11967945098876953 seconds
# Frame took 0.11318087577819824 seconds
# Frame took 0.12121462821960449 seconds
# Frame took 0.12923192977905273 seconds
# Frame took 0.11965131759643555 seconds
# Frame took 0.11269807815551758 seconds
# Frame took 0.11971426010131836 seconds
# Frame took 0.11565566062927246 seconds
# Frame took 0.11797904968261719 seconds
# Frame took 0.1318035125732422 seconds
# Frame took 0.13985443115234375 seconds
# Frame took 0.12788176536560059 seconds
# Frame took 0.11686062812805176 seconds
# Frame took 0.13189482688903809 seconds
# Frame took 0.12167668342590332 seconds
# Frame took 0.12789082527160645 seconds
# Frame took 0.11569070816040039 seconds
# Frame took 0.1161811351776123 seconds
# Frame took 0.1225893497467041 seconds
# Frame took 0.13064169883728027 seconds
# Frame took 0.11512565612792969 seconds
# Frame took 0.13064956665039062 seconds
# Frame took 0.12067866325378418 seconds
# Frame took 0.1177215576171875 seconds
# Frame took 0.11668562889099121 seconds
# Frame took 0.12961864471435547 seconds
# Frame took 0.12167644500732422 seconds
# Frame took 0.12778306007385254 seconds
# Frame took 0.11968159675598145 seconds
# Frame took 0.11382126808166504 seconds
# Frame took 0.1296555995941162 seconds
# Frame took 0.13364195823669434 seconds
# Frame took 0.11868119239807129 seconds
# Frame took 1.3930518627166748 seconds
# Frame took 0.9971306324005127 seconds
# Frame took 0.9821505546569824 seconds
# Frame took 1.0848720073699951 seconds
# Python int too large to convert to C long
# Frame took 0.9651854038238525 seconds
# Python int too large to convert to C long
# Frame took 0.0818932056427002 seconds
# Python int too large to convert to C long
# Frame took 0.08564567565917969 seconds
# Python int too large to convert to C long
# Frame took 0.08090353012084961 seconds
# Python int too large to convert to C long
# Frame took 0.08414292335510254 seconds
# Python int too large to convert to C long
# Frame took 0.08347749710083008 seconds
# Python int too large to convert to C long
# Frame took 0.08260607719421387 seconds
# Python int too large to convert to C long
# Frame took 0.08395028114318848 seconds
# Python int too large to convert to C long
# Frame took 0.08217644691467285 seconds
# Python int too large to convert to C long
# Frame took 0.08331012725830078 seconds
# Python int too large to convert to C long
# Frame took 0.08378291130065918 seconds
# Python int too large to convert to C long
# Frame took 0.0836648941040039 seconds
# Python int too large to convert to C long
# Frame took 0.11537289619445801 seconds
# Frame took 0.10519528388977051 seconds
# Frame took 0.09771990776062012 seconds
# Frame took 0.10151815414428711 seconds
# Frame took 0.09909510612487793 seconds
# Frame took 0.0987083911895752 seconds
# Frame took 0.10155177116394043 seconds
# Frame took 0.10221219062805176 seconds
# Frame took 0.10026025772094727 seconds
# Frame took 0.11196374893188477 seconds
# Frame took 0.1020956039428711 seconds
# Frame took 0.11290931701660156 seconds
# Frame took 0.10116696357727051 seconds
# Frame took 0.10884284973144531 seconds
# Frame took 0.1116800308227539 seconds
# Frame took 0.1156928539276123 seconds
# Frame took 0.11840176582336426 seconds
# Frame took 0.18416810035705566 seconds
# Frame took 0.16077899932861328 seconds
# Frame took 0.16672253608703613 seconds
# Frame took 0.15384650230407715 seconds
# Frame took 0.16736364364624023 seconds
# list index out of range
# 'NoneType' object is not iterable
# Frame took 0.08713984489440918 seconds
# list index out of range
# 'NoneType' object is not iterable
# Frame took 0.07878947257995605 seconds
# Frame took 0.09873604774475098 seconds
# Frame took 0.11671757698059082 seconds
# Frame took 0.1186530590057373 seconds
# Frame took 0.12070703506469727 seconds
# Frame took 0.1296236515045166 seconds
# Frame took 0.11726713180541992 seconds
# Frame took 0.11974740028381348 seconds
# Frame took 0.11570024490356445 seconds
# Frame took 0.11168932914733887 seconds
# Frame took 0.14321684837341309 seconds
# Frame took 0.15275096893310547 seconds
# Frame took 0.9793558120727539 seconds
# Frame took 0.9826817512512207 seconds
# Frame took 0.805201530456543 seconds
# Frame took 0.11523962020874023 seconds
# Frame took 0.12006831169128418 seconds
# Frame took 0.1785743236541748 seconds
# Frame took 0.15023589134216309 seconds
# Frame took 0.16567182540893555 seconds
# Frame took 0.14980626106262207 seconds
# Frame took 0.17173480987548828 seconds
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# Frame took 0.07982659339904785 seconds
# list index out of range
# 'NoneType' object is not iterable
# Frame took 0.08772706985473633 seconds
# Frame took 0.09976363182067871 seconds
# Frame took 0.11816096305847168 seconds
# Frame took 0.11768317222595215 seconds
# Frame took 0.11669731140136719 seconds
# Frame took 0.13364386558532715 seconds
# Frame took 0.1321570873260498 seconds
# Frame took 0.12865829467773438 seconds
# Frame took 0.1349489688873291 seconds
# Frame took 0.13958048820495605 seconds
# Frame took 0.1239171028137207 seconds
# Frame took 0.11671853065490723 seconds
# Frame took 0.12214088439941406 seconds
# Frame took 0.12665843963623047 seconds
# Frame took 0.11606383323669434 seconds
# Frame took 0.116943359375 seconds
# Frame took 0.1216583251953125 seconds
# Frame took 0.1129155158996582 seconds
# Frame took 0.12067055702209473 seconds
# Frame took 0.11073422431945801 seconds
# Frame took 0.11964988708496094 seconds
# Frame took 0.12865638732910156 seconds
# Frame took 0.11868548393249512 seconds
# Frame took 0.13387584686279297 seconds
# Frame took 0.1336519718170166 seconds
# Frame took 0.12983226776123047 seconds
# Frame took 0.15455317497253418 seconds
# Frame took 0.12865447998046875 seconds
# Frame took 0.13663601875305176 seconds
# Frame took 0.1313793659210205 seconds
# Frame took 0.14962053298950195 seconds
# Frame took 0.13463926315307617 seconds
# Frame took 0.13419818878173828 seconds
# Frame took 0.1498887538909912 seconds
# Frame took 0.13218331336975098 seconds
# Frame took 0.15062832832336426 seconds
# Frame took 0.13065671920776367 seconds
# Frame took 0.1338191032409668 seconds
# Frame took 0.14979839324951172 seconds
# Frame took 0.14879679679870605 seconds
# Frame took 0.13683843612670898 seconds
# Frame took 0.14776349067687988 seconds
# Frame took 0.14957046508789062 seconds
# Frame took 0.1346731185913086 seconds
# Frame took 0.13586664199829102 seconds
# Frame took 0.14504694938659668 seconds
# Frame took 0.135606050491333 seconds
# Frame took 0.13164710998535156 seconds
# Frame took 0.13458895683288574 seconds
# Frame took 0.1316814422607422 seconds
# Frame took 0.13468408584594727 seconds
# Frame took 0.13278818130493164 seconds
# Frame took 0.13489627838134766 seconds
# Frame took 0.13165020942687988 seconds
# Frame took 0.13605690002441406 seconds
# Frame took 0.12968659400939941 seconds
# Frame took 0.13364315032958984 seconds
# Frame took 0.13962745666503906 seconds
# Frame took 0.1436140537261963 seconds
# Frame took 0.13482928276062012 seconds
# Frame took 0.13168048858642578 seconds
# Frame took 0.13361001014709473 seconds
# Frame took 0.13422918319702148 seconds
# Frame took 0.14860200881958008 seconds
# Frame took 0.13518714904785156 seconds
# Frame took 0.13062047958374023 seconds
# Frame took 0.1376330852508545 seconds
# Frame took 0.1356360912322998 seconds
# Frame took 0.14560866355895996 seconds
# Frame took 0.13167929649353027 seconds
# Frame took 0.13361167907714844 seconds
# Frame took 0.13564133644104004 seconds
# Frame took 0.14817261695861816 seconds
# Frame took 0.13410258293151855 seconds
# Frame took 0.1496114730834961 seconds
# Frame took 0.15158557891845703 seconds
# Frame took 0.14862632751464844 seconds
# Frame took 0.15099525451660156 seconds
# Frame took 0.1463613510131836 seconds
# Frame took 0.15055537223815918 seconds
# Frame took 0.16817259788513184 seconds
# Frame took 0.15039706230163574 seconds
# Frame took 0.14916229248046875 seconds
# Frame took 0.14809703826904297 seconds
# Frame took 0.15420150756835938 seconds
# Frame took 0.13161349296569824 seconds
# Frame took 0.13509011268615723 seconds
# Frame took 0.14461326599121094 seconds
# Frame took 0.13563776016235352 seconds
# Frame took 0.13400864601135254 seconds
# Frame took 0.1469879150390625 seconds
# Frame took 0.13563799858093262 seconds
# Frame took 0.13283371925354004 seconds
# Frame took 0.13289332389831543 seconds
# Frame took 0.14062190055847168 seconds
# Frame took 0.1287233829498291 seconds
# Frame took 0.13031625747680664 seconds
# Frame took 0.11369442939758301 seconds
# Frame took 0.11898422241210938 seconds
# Frame took 0.11465692520141602 seconds
# Frame took 0.12081217765808105 seconds
# Frame took 0.12919902801513672 seconds
# Frame took 0.132645845413208 seconds
# Frame took 0.13481974601745605 seconds
# Frame took 0.13460707664489746 seconds
# Frame took 0.11372828483581543 seconds
# Frame took 0.13664460182189941 seconds
# Frame took 0.12861323356628418 seconds
# Frame took 0.13364720344543457 seconds
# Frame took 0.135636568069458 seconds
# Frame took 0.12785029411315918 seconds
# Frame took 0.11637687683105469 seconds
# Frame took 0.1237940788269043 seconds
# Frame took 0.11173129081726074 seconds
# Frame took 0.1326446533203125 seconds
# Frame took 0.11494255065917969 seconds
# Frame took 0.1212310791015625 seconds
# Frame took 0.11273026466369629 seconds
# Frame took 0.11765241622924805 seconds
# Frame took 0.11568880081176758 seconds
# Frame took 0.11568975448608398 seconds
# Frame took 0.11668920516967773 seconds
# Frame took 0.11868143081665039 seconds
# Frame took 0.11269783973693848 seconds
# Frame took 0.11971807479858398 seconds
# Frame took 0.11465620994567871 seconds
# Frame took 0.12270188331604004 seconds
# Frame took 0.1101076602935791 seconds
# Frame took 0.11861300468444824 seconds
# Frame took 0.11472678184509277 seconds
# Frame took 0.11671781539916992 seconds
# Frame took 0.11865806579589844 seconds
# Frame took 0.11572074890136719 seconds
# Frame took 0.11373496055603027 seconds
# Frame took 0.11649441719055176 seconds
# Frame took 0.11720132827758789 seconds
# Frame took 0.11990094184875488 seconds
# Frame took 0.11188411712646484 seconds
# Frame took 0.11864781379699707 seconds
# Frame took 0.11369442939758301 seconds
# Frame took 0.12031412124633789 seconds
# Frame took 0.1168527603149414 seconds
# Frame took 0.11372661590576172 seconds
# Frame took 0.11388945579528809 seconds
# Frame took 0.12070894241333008 seconds
# Frame took 0.11565637588500977 seconds
# Frame took 0.12198567390441895 seconds
# Frame took 0.1107034683227539 seconds
# Frame took 0.11690926551818848 seconds
# Frame took 0.11493062973022461 seconds
# Frame took 0.12019109725952148 seconds
# Frame took 0.11469459533691406 seconds
# Frame took 0.11791276931762695 seconds
# Frame took 0.11569809913635254 seconds
# Frame took 0.11668634414672852 seconds
# Frame took 0.13242268562316895 seconds
# Frame took 0.11534404754638672 seconds
# Frame took 0.11619091033935547 seconds
# Frame took 0.11946702003479004 seconds
# Frame took 0.11729574203491211 seconds
# Frame took 0.11668562889099121 seconds
# Frame took 0.12983250617980957 seconds
# Frame took 0.11768722534179688 seconds
# Frame took 0.11768722534179688 seconds
# Frame took 0.11771345138549805 seconds
# Frame took 0.11287379264831543 seconds
# Frame took 0.11867666244506836 seconds
# Frame took 0.12063407897949219 seconds
# Frame took 0.12728095054626465 seconds
# Frame took 0.11718940734863281 seconds
# Frame took 0.12272047996520996 seconds
# Frame took 0.12764453887939453 seconds
# Frame took 0.11871623992919922 seconds
# Frame took 0.11288881301879883 seconds
# Frame took 0.11891508102416992 seconds
# Frame took 0.11423993110656738 seconds
# Frame took 0.1188957691192627 seconds
# Frame took 0.11466264724731445 seconds
# Frame took 0.11903095245361328 seconds
# Frame took 0.11369609832763672 seconds
# Frame took 0.1209414005279541 seconds
# Frame took 0.11468935012817383 seconds
# Frame took 0.11967992782592773 seconds
# Frame took 0.11170101165771484 seconds
# Frame took 0.1187136173248291 seconds
# Frame took 0.11366629600524902 seconds
# Frame took 0.1216740608215332 seconds
# Frame took 0.11568856239318848 seconds
# Frame took 0.11469864845275879 seconds
# Frame took 0.11370062828063965 seconds
# Frame took 0.12015104293823242 seconds
# Frame took 0.11530137062072754 seconds
# Frame took 0.11689591407775879 seconds
# Frame took 0.11494779586791992 seconds
# Frame took 0.11865067481994629 seconds
# Frame took 0.11531448364257812 seconds
# Frame took 0.1186830997467041 seconds
# Frame took 0.11269903182983398 seconds
# Frame took 0.11961770057678223 seconds
# Frame took 0.11814188957214355 seconds
# Frame took 0.11673951148986816 seconds
# Frame took 0.11267733573913574 seconds
# Frame took 0.11964869499206543 seconds
# Frame took 0.11172914505004883 seconds
# Frame took 0.11965036392211914 seconds
# Frame took 0.11572122573852539 seconds
# Frame took 0.11783981323242188 seconds
# Frame took 0.11269783973693848 seconds
# Frame took 0.11789417266845703 seconds
# Frame took 0.11373209953308105 seconds
# Frame took 0.12272810935974121 seconds
# Frame took 0.11373567581176758 seconds
# Frame took 0.1150672435760498 seconds
# Frame took 0.11368680000305176 seconds
# Frame took 0.10069894790649414 seconds
# Frame took 0.11556673049926758 seconds
# Frame took 0.12066793441772461 seconds
# Frame took 0.11525845527648926 seconds
# Frame took 0.11768436431884766 seconds
# Frame took 0.1140437126159668 seconds
# Frame took 0.11967682838439941 seconds
# Frame took 0.11768603324890137 seconds
# Frame took 0.11374258995056152 seconds
# Frame took 0.0967257022857666 seconds
# Frame took 0.09873700141906738 seconds
# Frame took 0.10072922706604004 seconds
# Frame took 0.09842085838317871 seconds
# Frame took 0.1047370433807373 seconds
# Frame took 0.09869170188903809 seconds
# Frame took 0.09976696968078613 seconds
# Frame took 0.09969854354858398 seconds
# Frame took 0.10023784637451172 seconds
# Frame took 0.09677314758300781 seconds
# Frame took 0.10096096992492676 seconds
# Frame took 0.09994006156921387 seconds
# Frame took 0.09986162185668945 seconds
# Frame took 0.0987696647644043 seconds
# Frame took 0.10169792175292969 seconds
# Frame took 0.11589431762695312 seconds
# Frame took 0.11868143081665039 seconds
# Frame took 0.1127774715423584 seconds
# Frame took 0.12064599990844727 seconds
# Frame took 0.11369538307189941 seconds
# Frame took 0.11868715286254883 seconds
# Frame took 0.1137228012084961 seconds
# Frame took 0.11823391914367676 seconds
# Frame took 0.1141672134399414 seconds
# Frame took 0.11968493461608887 seconds
# Frame took 0.12956786155700684 seconds
# Frame took 0.11873269081115723 seconds
# Frame took 0.11360621452331543 seconds
# Frame took 0.119476318359375 seconds
# Frame took 0.11686420440673828 seconds
# Frame took 0.1147615909576416 seconds
# Frame took 0.11483883857727051 seconds
# Frame took 0.11771678924560547 seconds
# Frame took 0.11665821075439453 seconds
# Frame took 0.1216726303100586 seconds
# Frame took 0.10874128341674805 seconds
# Frame took 0.12064671516418457 seconds
# Frame took 0.11411190032958984 seconds
# Frame took 0.12064647674560547 seconds
# Frame took 0.11469364166259766 seconds
# Frame took 0.11672282218933105 seconds
# Frame took 0.11695313453674316 seconds
# Frame took 0.11586523056030273 seconds
# Frame took 0.11963796615600586 seconds
# Frame took 0.11366701126098633 seconds
# Frame took 0.11365175247192383 seconds
# Frame took 0.11973333358764648 seconds
# Frame took 0.11408209800720215 seconds
# Frame took 0.1186838150024414 seconds
# Frame took 0.11472439765930176 seconds
# Frame took 0.11903786659240723 seconds
# Frame took 0.11290740966796875 seconds
# Frame took 0.1216733455657959 seconds
# Frame took 0.11469435691833496 seconds
# Frame took 0.11569356918334961 seconds
# Frame took 0.11372852325439453 seconds
# Frame took 0.1186821460723877 seconds
# Frame took 0.11466217041015625 seconds
# Frame took 0.12171411514282227 seconds
# Frame took 0.11083149909973145 seconds
# Frame took 0.10372066497802734 seconds
# Frame took 0.11417937278747559 seconds
# Frame took 0.11730599403381348 seconds
# Frame took 0.11697602272033691 seconds
# Frame took 0.12064456939697266 seconds
# Frame took 0.10973668098449707 seconds
# Frame took 0.12064361572265625 seconds
# Frame took 0.11269783973693848 seconds
# Frame took 0.13763165473937988 seconds
# Frame took 0.14408588409423828 seconds
# Frame took 0.1525430679321289 seconds
# Frame took 0.14582157135009766 seconds
# Frame took 0.16752147674560547 seconds
# Frame took 0.15204119682312012 seconds
# Frame took 0.13068199157714844 seconds
# Frame took 0.13464665412902832 seconds
# Frame took 0.1356525421142578 seconds
# Frame took 0.12968111038208008 seconds
# Frame took 0.13560104370117188 seconds
# Frame took 0.1323680877685547 seconds
# Frame took 0.13267827033996582 seconds
# Frame took 0.1326615810394287 seconds
# Frame took 0.13164782524108887 seconds
# Frame took 0.13560748100280762 seconds
# Frame took 0.13064908981323242 seconds
# Frame took 0.11574268341064453 seconds
# Frame took 0.11920833587646484 seconds
# Frame took 0.1186819076538086 seconds
# Frame took 0.13157105445861816 seconds
# Frame took 0.11376261711120605 seconds
# Frame took 0.11979889869689941 seconds
# Frame took 0.11147809028625488 seconds
# Frame took 0.12229752540588379 seconds
# Frame took 0.11366486549377441 seconds
# Frame took 0.11773514747619629 seconds
# Frame took 0.11470723152160645 seconds
# Frame took 0.12120795249938965 seconds
# Frame took 0.14490389823913574 seconds
# Frame took 0.13369202613830566 seconds
# Frame took 0.13367509841918945 seconds
# Frame took 0.14860296249389648 seconds
# Frame took 0.1515944004058838 seconds
# Frame took 0.1495671272277832 seconds
# Frame took 0.1441967487335205 seconds
# Frame took 0.15564560890197754 seconds
# Frame took 0.15059971809387207 seconds
# Frame took 0.15011811256408691 seconds
# Frame took 0.1291649341583252 seconds
# Frame took 0.13903570175170898 seconds
# Frame took 0.13068151473999023 seconds
# Frame took 0.13364291191101074 seconds
# Frame took 0.13463973999023438 seconds
# Frame took 0.1316511631011963 seconds
# Frame took 0.13061904907226562 seconds
# Frame took 0.13566803932189941 seconds
# Frame took 0.1490788459777832 seconds
# Frame took 0.13510608673095703 seconds
# Frame took 0.1472010612487793 seconds
# Frame took 0.14962983131408691 seconds
# Frame took 0.167083740234375 seconds
# Frame took 0.15198040008544922 seconds
# Frame took 0.14875531196594238 seconds
# Frame took 0.16660189628601074 seconds
# Frame took 0.14768362045288086 seconds
# Frame took 0.14958691596984863 seconds
# Frame took 0.15081000328063965 seconds
# Frame took 0.1695418357849121 seconds
# Frame took 0.14421772956848145 seconds
# Frame took 0.17006897926330566 seconds
# Frame took 0.14813923835754395 seconds
# Frame took 0.148604154586792 seconds
# Frame took 0.1507863998413086 seconds
# Frame took 0.14695954322814941 seconds
# Frame took 0.13563895225524902 seconds
# Frame took 0.14761114120483398 seconds
# Frame took 0.15377140045166016 seconds
# Frame took 0.20046424865722656 seconds
# Frame took 0.20046615600585938 seconds
# Frame took 0.17954349517822266 seconds
# Frame took 0.16455912590026855 seconds
# Frame took 0.16458916664123535 seconds
# Frame took 0.15358805656433105 seconds
# Frame took 0.1495683193206787 seconds
# Frame took 0.1481459140777588 seconds
# Frame took 0.14857172966003418 seconds
# Frame took 0.1496295928955078 seconds
# Frame took 0.15089058876037598 seconds
# Frame took 0.15059828758239746 seconds
# Frame took 0.14962983131408691 seconds
# Frame took 0.14963650703430176 seconds
# Frame took 0.14960384368896484 seconds
# Frame took 0.14908432960510254 seconds
# Frame took 0.15334224700927734 seconds
# Frame took 0.16355299949645996 seconds
# Frame took 0.14860033988952637 seconds
# Frame took 0.15213894844055176 seconds
# Frame took 0.14897465705871582 seconds
# Frame took 0.15019869804382324 seconds
# Frame took 0.15101027488708496 seconds
# Frame took 0.1640782356262207 seconds
# Frame took 0.16771507263183594 seconds
# Frame took 0.1486034393310547 seconds
# Frame took 0.151641845703125 seconds
# Frame took 0.15273523330688477 seconds
# Frame took 0.1954808235168457 seconds
# Frame took 0.18252205848693848 seconds
# Frame took 0.1675112247467041 seconds
# Frame took 0.1699817180633545 seconds
# Frame took 0.14717960357666016 seconds
# Frame took 0.15003275871276855 seconds
# Frame took 0.14865946769714355 seconds
# Frame took 0.22147488594055176 seconds
# Frame took 0.23138141632080078 seconds
# Frame took 0.21637439727783203 seconds
# Frame took 0.22040987014770508 seconds
# Frame took 0.21343517303466797 seconds
# Frame took 0.2328803539276123 seconds
# Frame took 0.23467445373535156 seconds
# Frame took 0.21485185623168945 seconds
# Frame took 0.2339613437652588 seconds
# Frame took 0.23856091499328613 seconds
# Frame took 0.23138022422790527 seconds
# Frame took 0.23186254501342773 seconds
# Frame took 0.22838330268859863 seconds
# Frame took 0.2145860195159912 seconds
# Frame took 0.2428903579711914 seconds
# Frame took 0.22673320770263672 seconds
# Frame took 0.23042798042297363 seconds
# Frame took 0.21744084358215332 seconds
# Frame took 0.23387432098388672 seconds
# Frame took 0.21238136291503906 seconds
# Frame took 0.19870829582214355 seconds
# Frame took 0.16752147674560547 seconds
# Frame took 0.15178942680358887 seconds
# Frame took 0.148604154586792 seconds
# Frame took 0.15062642097473145 seconds
# Frame took 0.14873933792114258 seconds
# Frame took 0.15326189994812012 seconds
# Frame took 0.14661264419555664 seconds
# Frame took 0.14878463745117188 seconds
# Frame took 0.14856767654418945 seconds
# Frame took 0.15151095390319824 seconds
# Frame took 0.15220260620117188 seconds
# Frame took 0.14757132530212402 seconds
# Frame took 0.15063118934631348 seconds
# Frame took 0.148590087890625 seconds
# Frame took 0.1496114730834961 seconds
# Frame took 0.14956927299499512 seconds
# Frame took 0.1491687297821045 seconds
# Frame took 0.1499803066253662 seconds
# Frame took 0.14817190170288086 seconds
# Frame took 0.15159964561462402 seconds
# Frame took 0.14760661125183105 seconds
# Frame took 0.15223360061645508 seconds
# Frame took 0.14908337593078613 seconds
# Frame took 0.15059781074523926 seconds
# Frame took 0.14787554740905762 seconds
# Frame took 0.1537163257598877 seconds
# Frame took 0.14663934707641602 seconds
# Frame took 0.14957547187805176 seconds
# Frame took 0.1515636444091797 seconds
# Frame took 0.14860296249389648 seconds
# Frame took 0.15101075172424316 seconds
# Frame took 0.14769268035888672 seconds
# Frame took 0.15080809593200684 seconds
# Frame took 0.14818263053894043 seconds
# Frame took 0.16569948196411133 seconds
# Frame took 0.15245890617370605 seconds
# Frame took 0.14760661125183105 seconds
# Frame took 0.15259790420532227 seconds
# Frame took 0.14860844612121582 seconds
# Frame took 0.15261125564575195 seconds
# Frame took 0.14612960815429688 seconds
# Frame took 0.15561127662658691 seconds
# Frame took 0.14561152458190918 seconds
# Frame took 0.14859867095947266 seconds
# Frame took 0.15059709548950195 seconds
# Frame took 0.14763593673706055 seconds
# Frame took 0.15555214881896973 seconds
# Frame took 0.14484524726867676 seconds
# Frame took 0.1495985984802246 seconds
# Frame took 0.1488020420074463 seconds
# Frame took 0.1521754264831543 seconds
# Frame took 0.1501152515411377 seconds
# Frame took 0.14757061004638672 seconds
# Frame took 0.15113234519958496 seconds
# Frame took 0.1486053466796875 seconds
# Frame took 0.15159153938293457 seconds
# Frame took 0.1655876636505127 seconds
# Frame took 0.1515951156616211 seconds
# Frame took 0.14957165718078613 seconds
# Frame took 0.16755247116088867 seconds
# Frame took 0.1495966911315918 seconds
# Frame took 0.16307973861694336 seconds
# Frame took 0.1511671543121338 seconds
# Frame took 0.14942526817321777 seconds
# Frame took 0.1506335735321045 seconds
# Frame took 0.1515669822692871 seconds
# Frame took 0.18354225158691406 seconds
# Frame took 0.20270752906799316 seconds
# Frame took 0.21460676193237305 seconds
# Python int too large to convert to C long
# Frame took 0.11269998550415039 seconds
# Python int too large to convert to C long
# Frame took 0.10069918632507324 seconds
# Python int too large to convert to C long
# Frame took 0.09876680374145508 seconds
# Python int too large to convert to C long
# Frame took 0.1017303466796875 seconds
# Python int too large to convert to C long
# Frame took 0.10069751739501953 seconds
# Python int too large to convert to C long
# Frame took 0.0987694263458252 seconds
# Python int too large to convert to C long
# Frame took 0.10023832321166992 seconds
# Python int too large to convert to C long
# Frame took 0.09874892234802246 seconds
# Python int too large to convert to C long
# Frame took 0.09971976280212402 seconds
# Python int too large to convert to C long
# Frame took 0.10202693939208984 seconds
# Python int too large to convert to C long
# Frame took 0.09560894966125488 seconds
# Python int too large to convert to C long
# Frame took 0.0969839096069336 seconds
# Python int too large to convert to C long
# Frame took 0.08078479766845703 seconds
# Python int too large to convert to C long
# Frame took 0.08975744247436523 seconds
# Python int too large to convert to C long
# Frame took 0.09393072128295898 seconds
# Python int too large to convert to C long
# Frame took 0.08377552032470703 seconds
# Python int too large to convert to C long
# Frame took 0.0827784538269043 seconds
# Python int too large to convert to C long
# Frame took 0.08462667465209961 seconds
# Python int too large to convert to C long
# Frame took 0.08197975158691406 seconds
# Python int too large to convert to C long
# Frame took 0.08218574523925781 seconds
# Python int too large to convert to C long
# Frame took 0.09275197982788086 seconds
# Python int too large to convert to C long
# Frame took 0.34491991996765137 seconds
# Python int too large to convert to C long
# Frame took 0.07180905342102051 seconds
# Python int too large to convert to C long
# Frame took 0.07080483436584473 seconds
# Python int too large to convert to C long
# Frame took 0.0747976303100586 seconds
# Python int too large to convert to C long
# Frame took 0.06482815742492676 seconds
# Python int too large to convert to C long
# Frame took 0.06482529640197754 seconds
# Python int too large to convert to C long
# Frame took 0.06582045555114746 seconds
# Python int too large to convert to C long
# Frame took 0.06981277465820312 seconds
# Python int too large to convert to C long
# Frame took 0.10571789741516113 seconds
# Python int too large to convert to C long
# Frame took 0.10372185707092285 seconds
# Python int too large to convert to C long
# Frame took 0.08833098411560059 seconds
# Python int too large to convert to C long
# Frame took 0.10185122489929199 seconds
# Python int too large to convert to C long
# Frame took 0.11313819885253906 seconds
# Python int too large to convert to C long
# Frame took 0.11694860458374023 seconds
# Python int too large to convert to C long
# Frame took 0.12263917922973633 seconds
# Python int too large to convert to C long
# Frame took 0.10839509963989258 seconds
# Python int too large to convert to C long
# Frame took 0.11921167373657227 seconds
# Python int too large to convert to C long
# Frame took 0.11480903625488281 seconds
# Python int too large to convert to C long
# Frame took 0.11500859260559082 seconds
# Python int too large to convert to C long
# Frame took 0.12270426750183105 seconds
# Python int too large to convert to C long
# Frame took 0.1096951961517334 seconds
# Python int too large to convert to C long
# Frame took 0.11752462387084961 seconds
# Python int too large to convert to C long
# Frame took 0.11900901794433594 seconds
# Python int too large to convert to C long
# Frame took 0.11622905731201172 seconds
# Python int too large to convert to C long
# Frame took 0.12465548515319824 seconds
# Python int too large to convert to C long
# Frame took 0.10968279838562012 seconds
# Python int too large to convert to C long
# Frame took 0.11420392990112305 seconds
# Python int too large to convert to C long
# Frame took 0.11403489112854004 seconds
# Python int too large to convert to C long
# Frame took 0.10073375701904297 seconds
# Python int too large to convert to C long
# Frame took 0.10376381874084473 seconds
# Python int too large to convert to C long
# Frame took 0.11243057250976562 seconds
# Python int too large to convert to C long
# Frame took 0.11871623992919922 seconds
# Python int too large to convert to C long
# Frame took 0.11212539672851562 seconds
# Python int too large to convert to C long
# Frame took 0.10079526901245117 seconds
# Python int too large to convert to C long
# Frame took 0.10669755935668945 seconds
# Python int too large to convert to C long
# Frame took 0.10986447334289551 seconds
# Python int too large to convert to C long
# Frame took 0.11487221717834473 seconds
# Python int too large to convert to C long
# Frame took 0.10676240921020508 seconds
# Python int too large to convert to C long
# Frame took 0.11045408248901367 seconds
# Python int too large to convert to C long
# Frame took 0.11024951934814453 seconds
# Python int too large to convert to C long
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-86bc0f0c0e68> in <module>
#     179 last_time = time.time()
#     180 while True:
# --> 181     screen =  np.array(ImageGrab.grab(bbox=(0,40,800,640)))
#     182     print('Frame took {} seconds'.format(time.time()-last_time))
#     183     last_time = time.time()
#
# e:\program\anaconda\envs\tensorflow1\lib\site-packages\PIL\ImageGrab.py in grab(bbox)
#      43             "RGB", size, data,
#      44             # RGB, 32-bit line padding, origin lower left corner
# ---> 45             "raw", "BGR", (size[0]*3 + 3) & -4, -1
#      46             )
#      47     if bbox:
#
# e:\program\anaconda\envs\tensorflow1\lib\site-packages\PIL\Image.py in frombytes(mode, size, data, decoder_name, *args)
#    2409         args = mode
#    2410
# -> 2411     im = new(mode, size)
#    2412     im.frombytes(data, decoder_name, args)
#    2413     return im
#
# e:\program\anaconda\envs\tensorflow1\lib\site-packages\PIL\Image.py in new(mode, size, color)
#    2373         color = ImageColor.getcolor(color, mode)
#    2374
# -> 2375     return Image()._new(core.fill(mode, size, color))
#    2376
#    2377
#
# KeyboardInterrupt:
